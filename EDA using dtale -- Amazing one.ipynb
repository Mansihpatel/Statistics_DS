# %%
import dtale
import pandas as pd
import seaborn as sns 
from sklearn.datasets import load_diabetes

# %%
df = pd.read_csv("C:/Users/lenovo/python/EDA/Car_sales.csv")
dtale_carsale = dtale.show(df,ignore_duplicate=True)
# open it in new window
dtale_carsale.open_browser()

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'


if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

corr_data = df.corr(method='pearson')
corr_data.index.name = str('column')
corr_data = corr_data.reset_index()

# %%
corr_data
# Out:
#                  column  Sales_in_thousands  __year_resale_value  \
# 0    Sales_in_thousands            1.000000            -0.279034
# 1   __year_resale_value           -0.279034             1.000000
# 2    Price_in_thousands           -0.304734             0.953840
# 3           Engine_size            0.019983             0.531330
# 4            Horsepower           -0.197756             0.769081
# 5             Wheelbase            0.358179            -0.052270
# 6                 Width            0.140918             0.178767
# 7                Length            0.254980             0.026548
# 8           Curb_weight            0.008628             0.361557
# 9         Fuel_capacity            0.086540             0.325567
# 10      Fuel_efficiency           -0.016764            -0.399880
# 11    Power_perf_factor           -0.223252             0.827123
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase     Width  \
# ...

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df['new'] = df['Sales_in_thousands'] + df['Price_in_thousands']
# Out:
# 2021-02-16 12:15:24,602 - INFO     - NumExpr defaulting to 8 threads.

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...
